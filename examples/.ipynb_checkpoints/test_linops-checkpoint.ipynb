# %%
import sys
[sys.path.append(i) for i in ['.', '..']]
import torch
import numpy as np
import sigpy as sp
from sigpy.mri.app import L1WaveletRecon
from prox import Prox
from alg.eig import power_iter
from alg.cg import CG
from linear.linearmaps import LinearMap
from linear.mri import FFTCn, Sense
from linear.basics import Identity, Diff2d, Diff2dframe
import matplotlib.pyplot as plt
import copy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7e9f23693694> in <module>
#       3 import torch
#       4 import numpy as np
# ----> 5 import sigpy as sp
#       6 from sigpy.mri.app import L1WaveletRecon
#       7 from prox import Prox
#
# ModuleNotFoundError: No module named 'sigpy'

# %%
# FFT example
device0 = torch.device('cpu')
from skimage.data import shepp_logan_phantom
I_shepp = torch.tensor(shepp_logan_phantom()).to(device0)
Fop = FFTCn((400, 400), (400, 400), (0,1), norm = 'ortho')
k_shepp = Fop*I_shepp

# %%
plt.imshow(torch.log(torch.abs(k_shepp)).data.numpy())
plt.colorbar()

# %%
# MRI parallel imaging example (SENSE)
ex_multi = np.load('AXT2_210_6001736_layer11.npz')
device0 = torch.device('cpu')
k_c = torch.tensor(ex_multi['k_r'] + 1j*ex_multi['k_i']).to(device0)/32767.0
s_c = torch.tensor(ex_multi['s_r'] + 1j*ex_multi['s_i']).to(device0)/32767.0
(nc, nh, nw) = s_c.shape
Fop = FFTCn((nc, nh, nw), (nc, nh, nw), (1,2), norm = 'ortho')
I1 = Fop.H*k_c
I1 = torch.sqrt(I1.abs().pow(2).sum(dim=0))
mask = torch.zeros(nh,nw)
mask[:,0:nw:8]=1
Sop = Sense((nh, nw), (nc, nh, nw), (0,1), s_c, mask, batchmode = False)
I0 = Sop.H*k_c
plt.figure(figsize=(20,10))
plt.imshow(torch.abs(I0).data.numpy())
plt.colorbar()

# %%
I = Identity(Sop.size_in, Sop.size_in)
CG_tik = CG(Sop.H*Sop+0.5*I,max_iter = 2)

# %%
T = Diff2d(Sop.size_in, dim = (0,1))
CG_tik = CG(Sop.H*Sop+0.02*T.H*T, max_iter = 50)

# %%
T = Diff2dframe(Sop.size_in, dim = (0,1))
CG_tik = CG(Sop.H*Sop+0.001*T)

# %%
I0.requires_grad_()
# Out:
# tensor([[0.+0.j, 0.+0.j, 0.+0.j,  ..., 0.+0.j, 0.+0.j, 0.+0.j],
#         [0.+0.j, 0.+0.j, 0.+0.j,  ..., 0.+0.j, 0.+0.j, 0.+0.j],
#         [0.+0.j, 0.+0.j, 0.+0.j,  ..., 0.+0.j, 0.+0.j, 0.+0.j],
#         ...,
#         [0.+0.j, 0.+0.j, 0.+0.j,  ..., 0.+0.j, 0.+0.j, 0.+0.j],
#         [0.+0.j, 0.+0.j, 0.+0.j,  ..., 0.+0.j, 0.+0.j, 0.+0.j],
#         [0.+0.j, 0.+0.j, 0.+0.j,  ..., 0.+0.j, 0.+0.j, 0.+0.j]],
#        dtype=torch.complex128, requires_grad=True)

# %%
I_tik = CG_tik.run(I0, I0)
# Out:
# residual at 1th iter: 0.0007051355015604329
# residual at 2th iter: 7.77385877000149e-06

# %%
torch.sum(I_tik).backward()
# Out:
# dx tensor([[1.+0.j, 1.+0.j, 1.+0.j,  ..., 1.+0.j, 1.+0.j, 1.+0.j],
#         [1.+0.j, 1.+0.j, 1.+0.j,  ..., 1.+0.j, 1.+0.j, 1.+0.j],
#         [1.+0.j, 1.+0.j, 1.+0.j,  ..., 1.+0.j, 1.+0.j, 1.+0.j],
#         ...,
#         [1.+0.j, 1.+0.j, 1.+0.j,  ..., 1.+0.j, 1.+0.j, 1.+0.j],
#         [1.+0.j, 1.+0.j, 1.+0.j,  ..., 1.+0.j, 1.+0.j, 1.+0.j],
#         [1.+0.j, 1.+0.j, 1.+0.j,  ..., 1.+0.j, 1.+0.j, 1.+0.j]],
#        dtype=torch.complex128)
# residual at 1th iter: 1370.746583647398
# residual at 2th iter: 31.946216433330022

# %%
plt.figure(figsize=(20,10))
plt.imshow(torch.abs(I_tik).data.numpy())
plt.colorbar()

# %%
plt.figure(figsize=(20,10))
plt.imshow(torch.abs(I_tik).data.numpy())
plt.colorbar()

# %%
plt.figure(figsize=(20,10))
plt.imshow(torch.abs(Sop.H*Sop*Sop.H*Sop*Sop.H*k_c).data.numpy())
plt.colorbar()

# %%
plt.figure(figsize=(20,10))
plt.imshow(torch.abs(Sop.H*Sop*Sop.H*k_c).data.numpy())
plt.colorbar()

# %%
plt.figure(figsize=(20,10))
plt.imshow(torch.abs(Sop.H*k_c).data.numpy())
plt.colorbar()

# %%
k_c - Sop*Sop.H*k_c

# %%
a = tuple(torch.tensor([2,3]))

# %%
a[0]
